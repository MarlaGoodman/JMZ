# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/marleegoodman/Dropbox/My Mac (Marlee’s MacBook Air)/Desktop/JMZ.csv')
pd.set_option('display.max_columns', None)
pd.set_option("max_rows", None)
df.drop(['MasseraA','VirginiaB','JacobOA'],axis=1,inplace=True)
df
# Out:
#    Alina   Danny Lauren  MikeB   Mike Sabriyya Srey  Trina     AJ   Esti  \
# 0   Green  Green  Green  Green    NaN      Red  NaN    Red  Green    Red
# 1     Red    Red  Green    Red    NaN      Red  NaN    Red    Red    Red
# 2     Red  Green  Green    Red    NaN    Green  NaN  Green  Green  Green
# 3     Red    Red  Green    Red    NaN    Green  NaN  Green    Red  Green
# 4   Green  Green    Red    Red    NaN      Red  NaN    Red    Red    Red
# 5   Green  Green  Green    Red    NaN      Red  NaN    Red  Green  Green
# 6   Green    Red  Green    Red    NaN      Red  NaN    Red  Green    Red
# 7     Red  Green  Green    Red    NaN    Green  NaN    Red    Red    Red
# 8     Red  Green    Red  Green    NaN    Green  NaN  Green  Green    Red
# 9     Red  Green  Green    Red    NaN      Red  NaN  Green  Green    Red
# 10  Green    Red  Green  Green    NaN      Red  NaN    Red    Red    Red
# 11  Green  Green  Green  Green    NaN    Green  NaN    Red    Red    Red
# ...

# %%
import matplotlib.pyplot as plt

# %%
dfg=df.apply(pd.Series.value_counts)
dfg
# Out:
#        Alina   Danny  Lauren  MikeB  Mike  Sabriyya  Srey  Trina  AJ  Esti  \
# Green      16     20      24     10     1        16   NaN      7  11    14
# Red        13      9       5     17     1        13   2.0     22  18    15
#
#        Ivonne  JH  Kevin  Luis  MasseraB  VirginiaA  Franz  JacobOB  Kirsten  \
# Green       4  18     14     8         2          1      9       11       10
# Red        25  11     15    21        25          8     20       18       19
#
#        Vivian  TiaraB  TiaraA  Belkis  Jack  Jake N  Sunny  MelNick  Peter  \
# Green      11     NaN      11      16    19      23     11        9      3
# Red        18     2.0      18      13    10       6     18       20     26
#
#        YashiraMichael  PhilipTommy
# Green              11            3
# Red                18           26

# %%
plt.figure(figsize=(10, 10))
dfg.iloc[0].sort_values(ascending=False).plot(kind='bar')
plt.show()

# %%
perc=dfg.iloc[0]/29
perc.sort_values(ascending=False).plot(kind='bar')

# %%
plt.figure(figsize=(10, 10))
dfg.iloc[1].sort_values(ascending=False).plot(kind='box')
plt.show()
